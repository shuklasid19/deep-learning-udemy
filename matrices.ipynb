# %%
import pandas as pd

# %%
import os

# %%
stats = pd.read_csv("C:/Users/sid/Desktop/P4-Demographic-Data.csv")

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['Birth rate', 'Internet users']]
# Out:
#      Birth rate  Internet users
# 0        10.244        78.90000
# 1        35.253         5.90000
# 2        45.985        19.10000
# 3        12.877        57.20000
# 4        11.044        88.00000
# 5        17.716        59.90000
# 6        13.308        41.90000
# 7        16.447        63.40000
# 8        13.200        83.00000
# 9         9.400        80.61880
# 10       18.300        58.70000
# 11       44.151         1.30000
# 12       11.200        82.17020
# 13       36.440         4.90000
# 14       40.551         9.10000
# 15       20.142         6.63000
# 16        9.200        53.06150
# 17       15.040        90.00004
# 18       15.339        72.00000
# 19        9.062        57.79000
# 20       12.500        54.17000
# 21       23.092        33.60000
# 22       10.400        95.30000
# 23       24.236        36.94000
# 24       14.931        51.04000
# 25       12.188        73.00000
# 26       16.405        64.50000
# 27       18.134        29.90000
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.shape
# Out:
# (195, 5)

# %%
 stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
#top rows
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
##renaming columns of a dataframe

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['Country Name', 'Country Code', 
                 'Birth rate', 'Internet users','Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = ['countryname', 'countrycode', 'birthdate', 'internetusers', 'incomegroup']

# %%
###subsetting dataframes

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#three parts. Buckle up!
# -rows
# -columns
# -combine the two

# %%
#part 1.rows

# %%
stats[:10]
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[ : :-1] #reverse
# Out:
#                         countryname countrycode  birthdate  internetusers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# ...

# %%
#get inly every 20th country:
stats[::20]
# Out:
#     countryname countrycode  birthdate  internetusers          incomegroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
#2columns

# %%
stats.columns
# Out:
# Index(['countryname', 'countrycode', 'birthdate', 'internetusers',
#        'incomegroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['countryname']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
stats[['countryname', 'birthdate']].head()
# Out:
#             countryname  birthdate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats[['birthdate', 'countryname']].head()
# Out:
#    birthdate           countryname
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
stats.birthdate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: birthdate, dtype: float64

# %%
df1 = stats[4:8][['countryname', 'birthdate']]

# %%
df2 = stats[['countryname', 'birthdate']][8:12]

# %%
result = stats.birthdate * stats.internetusers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
stats["Mycalc"] =  stats.birthdate * stats.internetusers

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup    Mycalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats['xyz'] = [1,2,3,4] 
#not proper with given vals
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-673bc78ad715> in <module>()
# ----> 1 stats['xyz'] = [1,2,3,4]
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
#    3387             # turn me into an ndarray
# ...

# %%
#removing a column
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup    Mycalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats = stats.drop('Mycalc', 1)

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#filtering dataframe its about rows

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.internetusers <=2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: internetusers, Length: 195, dtype: bool

# %%
stats[stats.internetusers <=2]
# Out:
#       countryname countrycode  birthdate  internetusers          incomegroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
filte = stats.internetusers>2
stats[30:40]
# Out:
#       countryname countrycode  birthdate  internetusers          incomegroup
# 30         Canada         CAN     10.900          85.80          High income
# 31    Switzerland         CHE     10.200          86.34          High income
# 32          Chile         CHL     13.385          66.50          High income
# 33          China         CHN     12.100          45.80  Upper middle income
# 34  Cote d'Ivoire         CIV     37.320           8.40  Lower middle income
# 35       Cameroon         CMR     37.236           6.40  Lower middle income
# 36    Congo, Rep.         COG     37.011           6.60  Lower middle income
# 37       Colombia         COL     16.076          51.70  Upper middle income
# 38        Comoros         COM     34.326           6.50           Low income
# 39     Cabo Verde         CPV     21.625          37.50  Lower middle income

# %%
stats[filte]
# Out:
#                         countryname countrycode  birthdate  internetusers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 12                          Belgium         BEL     11.200       82.17020
# ...

# %%
birth = stats.birthdate > 40

# %%
stats[birth]
# Out:
#           countryname countrycode  birthdate  internetusers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              incomegroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats[stats.birthdate>40]
# Out:
#           countryname countrycode  birthdate  internetusers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              incomegroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
b = [stats.birthdate>40] and [stats.internetusers < 2]

# %%
filter1 = stats.birthdate > 50
filter2 = stats.internetusers < 2

# %%
filter1 & filter2 #element by element
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
stats[[filter1 & filter2]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-86ac9a4bae57> in <module>()
# ----> 1 stats[[filter1 & filter2]]
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2714             elif len(key) != len(self.index):
#    2715                 raise ValueError('Item wrong length %d instead of %d.' %
# -> 2716                                  (len(key), len(self.index)))
# ...

# %%
stats[(stats.internetusers > 40) & (stats.birthdate > 23)]
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 88               Jordan         JOR     27.046           41.0
# 188  West Bank and Gaza         PSE     30.394           46.6
#
#              incomegroup
# 88   Upper middle income
# 188  Lower middle income

# %%
stats.incomegroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
high = stats[stats.incomegroup == 'High income']
low = stats[stats.incomegroup == 'Low income']
upper = stats[stats.incomegroup == 'Upper middle income']
lower  = stats[stats.incomegroup == 'Lower middle income']

# %%
stats[stats.countryname == 'Malta']
# Out:
#     countryname countrycode  birthdate  internetusers  incomegroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
#quick exercise
#find out everything about malta
# Out:
#     countryname countrycode  birthdate  internetusers  incomegroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
stats.head()
# Out:
#             countryname countrycode  birthdate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#at #for labels, integers are treated as labels
#.iat #for integer location

# %%
stats.iat[3, 4]
# Out:
# 'Upper middle income'

# %%
stats.iat[2,2]
# Out:
# 45.985

# %%
stats.at[2, 'birthdate']
# Out:
# 45.985

# %%
stats.at[3, 'birthdate']
# Out:
# 12.877

# %%
sub10 = stats[::10]
#every 10th value

# %%
sub10
# Out:
#      countryname countrycode  birthdate  internetusers          incomegroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10, 0]
# Out:
# 'Libya'

# %%
sub10.at[10, 'countryname'] #takes label not the value
# Out:
# 'Azerbaijan'

# %%
sub10.at[12, 'countryname']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-137eaabde735> in <module>()
# ----> 1 sub10.at[12, 'countryname']
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# ~\Anaconda3\envs\the_best_chatbot\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2534
#    2535         try:
# -> 2536             return engine.get_value(series._values, index)
#    2537         except (TypeError, ValueError):
#    2538
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# ...

# %%
#seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 8,4

# %%
#distribution:
visl = sns.distplot(stats['internetusers'])

# %%
sns.distplot(stats['birthdate'], bins=20)

# %%
visl = sns.distplot(stats['internetusers'],bins=30)

# %%
vis2 = sns.boxplot(data=stats, x="incomegroup", y="birthdate")

# %%
sns.boxplot(data=stats, x="internetusers", y="birthdate")
#x and y are features

# %%
#seaborn gal

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate", fit_reg=False, )

# %%
vis4 = sns.distplot(stats['birthdate'], bins=30)

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup' )

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup' , size=8)

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup' , aspect=0.5 , size=10)

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup'  , size=10)

# %%
#marker size

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup'  , size=8 , markers='*',
                 scatter_kws={'s':200})

# %%
vis3 = sns.lmplot(data = stats, x="internetusers", y="birthdate",
                  fit_reg=False,hue='incomegroup'  , size=8 ,
                 scatter_kws={'s':200})
